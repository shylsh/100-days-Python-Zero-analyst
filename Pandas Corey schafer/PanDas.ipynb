# %%
import pandas as pd
import os

# %%
df1 = pd.read_csv(r'F:\Github\100-days-Python-Zero-analyst\day16_emp_data.csv')

# %%
df1
# Out:
#         ID         Full Name               Job Title   Department  Gender  \
# 0   E02002            Kai Le       Controls Engineer  Engineering    Male
# 1   E02003      Robert Patel                 Analyst        Sales    Male
# 2   E02004        Cameron Lo   Network Administrator           IT    Male
# 3   E02005   Harper Castillo    IT Systems Architect           IT  Female
# 4   E02006               NaN                     NaN          NaN     NaN
# 5   E02007               NaN                     NaN          NaN     NaN
# 6   E02008           Jade Hu             Sr. Analyst   Accounting  Female
# 7   E02009       Miles Chang              Analyst II      Finance    Male
# 8   E02010     Gianna Holmes   System Administrator†           IT  Female
# 9   E02011    Jameson Thomas                 Manager      Finance    Male
# 10  E02012      Jameson Pena         Systems Analyst           IT    Male
# 11  E02013          Bella Wu                     NaN      Finance  Female
# ...

# %%
df1.shape
# Out:
# (23, 11)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          23 non-null     object
#  1   Full Name   21 non-null     object
#  2   Job Title   18 non-null     object
#  3   Department  21 non-null     object
#  4   Gender      21 non-null     object
#  5   Age         21 non-null     float64
#  6   Hire Date   14 non-null     object
#  7   Salary      21 non-null     object
#  8   Country     17 non-null     object
#  9   City        23 non-null     object
#  10  Exit Date   2 non-null      object
# dtypes: float64(1), object(10)
# memory usage: 2.1+ KB

# %%
pd.set_option('display.max_columns', None)
df
# Out:
#         ID         Full Name               Job Title   Department  Gender  \
# 0   E02002            Kai Le       Controls Engineer  Engineering    Male
# 1   E02003      Robert Patel                 Analyst        Sales    Male
# 2   E02004        Cameron Lo   Network Administrator           IT    Male
# 3   E02005   Harper Castillo    IT Systems Architect           IT  Female
# 4   E02006               NaN                     NaN          NaN     NaN
# 5   E02007               NaN                     NaN          NaN     NaN
# 6   E02008           Jade Hu             Sr. Analyst   Accounting  Female
# 7   E02009       Miles Chang              Analyst II      Finance    Male
# 8   E02010     Gianna Holmes   System Administrator†           IT  Female
# 9   E02011    Jameson Thomas                 Manager      Finance    Male
# 10  E02012      Jameson Pena         Systems Analyst           IT    Male
# 11  E02013          Bella Wu                     NaN      Finance  Female
# ...

# %%
df.head()
# Out:
#        ID        Full Name              Job Title   Department  Gender   Age  \
# 0  E02002           Kai Le      Controls Engineer  Engineering    Male  47.0
# 1  E02003     Robert Patel                Analyst        Sales    Male  58.0
# 2  E02004       Cameron Lo  Network Administrator           IT    Male  34.0
# 3  E02005  Harper Castillo   IT Systems Architect           IT  Female  39.0
# 4  E02006              NaN                    NaN          NaN     NaN   NaN
#
#     Hire Date    Salary        Country      City Exit Date
# 0    02/05/22  $92,368   United States  Columbus       NaN
# 1  10/23/2013  $45,703   United States   Chicago       NaN
# 2   3/24/2019  $83,576           China  Shanghai       NaN
# 3    04/07/18  $98,062   United States   Seattle       NaN
# 4         NaN       NaN            NaN    Austin       NaN

# %%
person = {
    "first": "Corey", 
    "last": "Schafer", 
    "email": "CoreyMSchafer@gmail.com"
}

# %%
people = {
    "first": ["Corey"], 
    "last": ["Schafer"], 
    "email": ["CoreyMSchafer@gmail.com"]
}

# %%
people = {
    "first": ["Corey", 'Jane', 'John'], 
    "last": ["Schafer", 'Doe', 'Doe'], 
    "email": ["CoreyMSchafer@gmail.com", 'JaneDoe@email.com', 'JohnDoe@email.com']
}

# %%
people['email']
# Out:
# ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com']

# %%
people['email'][:2]
# Out:
# ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com']

# %%
df= pd.DataFrame(people)
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df['email']
# Out:
# 0    CoreyMSchafer@gmail.com
# 1          JaneDoe@email.com
# 2          JohnDoe@email.com
# Name: email, dtype: object

# %%
type(df['email'])
# Out:
# pandas.core.series.Series

# %%
type(people['email'])
# Out:
# list

# %%
df.email
# Out:
# 0    CoreyMSchafer@gmail.com
# 1          JaneDoe@email.com
# 2          JohnDoe@email.com
# Name: email, dtype: object

# %%
df.count()
# Out:
# first    3
# last     3
# email    3
# dtype: int64

# %%
df[['email', 'last']]
# Out:
#                      email     last
# 0  CoreyMSchafer@gmail.com  Schafer
# 1        JaneDoe@email.com      Doe
# 2        JohnDoe@email.com      Doe

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df.iloc[0]
# Out:
# first                      Corey
# last                     Schafer
# email    CoreyMSchafer@gmail.com
# Name: 0, dtype: object

# %%
df.iloc[[0,1],2]  # inner brackets mean rows and columns
# Out:
# 0    CoreyMSchafer@gmail.com
# 1          JaneDoe@email.com
# Name: email, dtype: object

# %%
df.loc[[0,1],['email','last']]
# Out:
#                      email     last
# 0  CoreyMSchafer@gmail.com  Schafer
# 1        JaneDoe@email.com      Doe

# %%
df1.shape
# Out:
# (23, 11)

# %%
df1.columns
# Out:
# Index(['ID', 'Full Name', 'Job Title', 'Department', 'Gender', 'Age',
#        'Hire Date', 'Salary', 'Country', 'City', 'Exit Date'],
#       dtype='object')

# %%
df1['Gender'].value_counts()
# Out:
# Gender
# Male      11
# Female    10
# Name: count, dtype: int64

# %%
df1.loc[0:2,'Gender' : 'Salary']
# Out:
#   Gender   Age   Hire Date    Salary
# 0   Male  47.0    02/05/22  $92,368
# 1   Male  58.0  10/23/2013  $45,703
# 2   Male  34.0   3/24/2019  $83,576

# %%
df1.set_index('ID', inplace= True)

# %%
df1.head()
# Out:
#               Full Name              Job Title   Department  Gender   Age  \
# ID
# E02002           Kai Le      Controls Engineer  Engineering    Male  47.0
# E02003     Robert Patel                Analyst        Sales    Male  58.0
# E02004       Cameron Lo  Network Administrator           IT    Male  34.0
# E02005  Harper Castillo   IT Systems Architect           IT  Female  39.0
# E02006              NaN                    NaN          NaN     NaN   NaN
#
#          Hire Date    Salary        Country      City Exit Date
# ID
# E02002    02/05/22  $92,368   United States  Columbus       NaN
# E02003  10/23/2013  $45,703   United States   Chicago       NaN
# E02004   3/24/2019  $83,576           China  Shanghai       NaN
# E02005    04/07/18  $98,062   United States   Seattle       NaN
# E02006         NaN       NaN            NaN    Austin       NaN

# %%
df1.index
# Out:
# Index(['E02002', 'E02003', 'E02004', 'E02005', 'E02006', 'E02007', 'E02008',
#        'E02009', 'E02010', 'E02011', 'E02012', 'E02013', 'E02014', 'E02015',
#        'E02016', 'E02017', 'E02018', 'E02019', 'E02020', 'E02021', 'E02022',
#        'E02023', 'E02024'],
#       dtype='object', name='ID')

# %%
df1.loc[['E02002','E02006'],'Age':'City']
# Out:
#          Age Hire Date    Salary        Country      City
# ID
# E02002  47.0  02/05/22  $92,368   United States  Columbus
# E02006   NaN       NaN       NaN            NaN    Austin

# %%
# to reset the index
df1.reset_index(inplace=True)
df1.head()
# Out:
#        ID        Full Name              Job Title   Department  Gender   Age  \
# 0  E02002           Kai Le      Controls Engineer  Engineering    Male  47.0
# 1  E02003     Robert Patel                Analyst        Sales    Male  58.0
# 2  E02004       Cameron Lo  Network Administrator           IT    Male  34.0
# 3  E02005  Harper Castillo   IT Systems Architect           IT  Female  39.0
# 4  E02006              NaN                    NaN          NaN     NaN   NaN
#
#     Hire Date    Salary        Country      City Exit Date
# 0    02/05/22  $92,368   United States  Columbus       NaN
# 1  10/23/2013  $45,703   United States   Chicago       NaN
# 2   3/24/2019  $83,576           China  Shanghai       NaN
# 3    04/07/18  $98,062   United States   Seattle       NaN
# 4         NaN       NaN            NaN    Austin       NaN

# %%
df1.set_index('ID', inplace= True)

# %%
df1.sort_index(ascending=False).head()
# Out:
#                Full Name               Job Title  Department  Gender   Age  \
# ID
# E02024      Serenity Cao  Account Representative       Sales  Female  31.0
# E02023     Lillian Lewis     Technical Architect          IT  Female  43.0
# E02022          Eli Dang             Sr. Manager  Accounting    Male  45.0
# E02021  Sophia Gutierrez                 Manager  Accounting  Female  63.0
# E02020      Jordan Kumar    Service Desk Analyst          IT    Male  29.0
#
#          Hire Date     Salary        Country      City  Exit Date
# ID
# E02024  10/21/2018   $66,721           China  Shanghai        NaN
# E02023   8/14/2013   $83,323   United States   Phoenix  3/31/2019
# E02022  11/16/2015  $122,875   United States   Chicago        NaN
# E02021    02/08/09  $102,649   United States    Austin        NaN
# E02020    11/11/17   $95,729   United States   Seattle        NaN

# %%
df1.reset_index(inplace=True)
df1.head()
# Out:
#    index      ID        Full Name              Job Title   Department  Gender  \
# 0      0  E02002           Kai Le      Controls Engineer  Engineering    Male
# 1      1  E02003     Robert Patel                Analyst        Sales    Male
# 2      2  E02004       Cameron Lo  Network Administrator           IT    Male
# 3      3  E02005  Harper Castillo   IT Systems Architect           IT  Female
# 4      4  E02006              NaN                    NaN          NaN     NaN
#
#     Age   Hire Date    Salary        Country      City Exit Date
# 0  47.0    02/05/22  $92,368   United States  Columbus       NaN
# 1  58.0  10/23/2013  $45,703   United States   Chicago       NaN
# 2  34.0   3/24/2019  $83,576           China  Shanghai       NaN
# 3  39.0    04/07/18  $98,062   United States   Seattle       NaN
# 4   NaN         NaN       NaN            NaN    Austin       NaN
